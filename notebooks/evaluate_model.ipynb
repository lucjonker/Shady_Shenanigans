# %%
import torch
from src.evaluator import ShadeEvaluator
from datetime import datetime
import pytz

# %%
# Instantiate Evaluator
RESULTS_DIR = "/Users/luc/Geomatics/Thesis/ShadyShenanigans/results/"
STATE_DICT_DIR = "/Users/luc/Geomatics/Thesis/ShadyShenanigans/resources/"
device = torch.device("mps" if torch.backends.mps.is_available()
                      else "cuda" if torch.cuda.is_available()
else "cpu")

evaluator = ShadeEvaluator(device, STATE_DICT_DIR, RESULTS_DIR)

# %%
# Test evaluation
test_tile = "/Users/luc/Geomatics/Thesis/Data/input/271110_Ams/test_tiles/dsms/combined/271110_p_176_2022_06_02_dsm.tif"
# date_time = datetime.now(pytz.utc)
date_time = datetime(2024, 5, 15, 10, 30, 0, 0)
a = pytz.timezone("Europe/Amsterdam")
date_time = a.localize(date_time, is_dst=False)

evaluator.evaluate(test_tile, date_time)
# Out:
# 40.856996019204075 114.57651210991672
